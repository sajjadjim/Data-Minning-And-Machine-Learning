# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

df=pd.read_csv("/content/drive/MyDrive/Dataset Data Mining /Dataset/iris.csv")

#show Data set
print(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.4           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.3          0.2     setosa
# 4             5.1          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Deatils Description Print
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# None

# %%
#Two Column Print
stat.mean(df['sepal_length'])
# Out:
# 5.844

# %%
stat.median(df['sepal_length'])
# Out:
# 5.8

# %%
np.percentile(df['sepal_length'],50)
# Out:
# 5.8

# %%
df['sepal_length'].quantile([0.05,0.25,0.5,0.75])
# Out:
# 0.05    4.6
# 0.25    5.1
# 0.50    5.8
# 0.75    6.4
# Name: sepal_length, dtype: float64

# %%
#Find out the variance petal length
stat.variance(df['petal_length'])
# Out:
# 3.119509619686801

# %%
#Standerd Daviation find out the petal length
stat.stdev(df['petal_length'])
# Out:
# 1.766213356219118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.844000     3.056667      3.757333     1.198667
# std        0.827423     0.434489      1.766213     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal_length'].plot(kind='hist', bins=20, title='sepal_length')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['sepal_width'].plot(kind='hist', bins=20, title='sepal_width')
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X =[10,5,20,15,35]
Y=[15,25,35,20,7]
plt.plot(X,color='r' ,linestyle=':',linewidth=2, marker='o')
plt.plot(Y,color='g' ,linestyle=':',linewidth=2, marker='o')
plt.show()

# %%
X=[10,2,20,15,35]
t.subplot(2,2,1)
t.plot(X,color='r' ,linestyle=':',linewidth=2, marker='*',lebel='Dash')
t.legend()

t.subplot(2,2,2)
t.plot(X,color='g' ,linestyle='--',linewidth=2, marker='s',lebel='Dash')
t.legend()
t.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-14f9abc9c7b4> in <cell line: 2>()
#       1 X=[10,2,20,15,35]
# ----> 2 t.subplot(2,2,1)
#       3 t.plot(X,color='r' ,linestyle=':',linewidth=2, marker='*',lebel='Dash')
#       4 t.legend()
#       5
#
# NameError: name 't' is not defined
