# %%
a =10
b=4.8

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a//b)

print(type(a))
print(type(b))
# Out:
# 14.8
# 5.2
# 48.0
# 2.0833333333333335
# 0.40000000000000036
# 2.0
# <class 'int'>
# <class 'float'>

# %%
sprit= "My name is Mr.Kasem"
print(sprit)
# Out:
# My name is Mr.Kasem

# %%
str1 = "DML is "
str2 = "Data Manipulation Language"
print(str1+str2)
# Out:
# DML is Data Manipulation Language
