# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

df=pd.read_csv("/content/drive/MyDrive/Dataset Data Mining /Dataset/train.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# PassengerId       0.000000
# Survived          0.000000
# Pclass            0.000000
# Name              0.000000
# Sex               0.000000
# Age              19.865320
# SibSp             0.000000
# Parch             0.000000
# Ticket            0.000000
# Fare              0.000000
# Cabin            77.104377
# Embarked          0.224467
# sepal_length    100.000000
# sepal_width     100.000000
# dtype: float64

# %%
age_missing_index  = df[df['Age'].isnull()].index.tolist()

# %%
train_1= df.copy()
train_1["Age"].fillna(30,inplace=True)
train_1.isnull().sum()
# Out:
# <ipython-input-10-abec800e4468>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_1["Age"].fillna(30,inplace=True)
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin           687
# Embarked          2
# sepal_length    891
# sepal_width     891
# dtype: int64

# %%
train_1.iloc[age_missing_index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
train_constant = df.copy()

cos_imputer = SimpleImputer (strategy = 'constant', fill_value = '-1')
train_constant.iloc[:,:]=cos_imputer.fit_transform(train_constant)
#
train_constant.isnull().sum()
# Out:
# <ipython-input-12-0b8746535a9b>:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[22.0, 38.0, 26.0, 35.0, 35.0, '-1', 54.0, 2.0, 27.0, 14.0, 4.0, 58.0, 20.0, 39.0, 14.0, 55.0, 2.0, '-1', 31.0, '-1', 35.0, 34.0, 15.0, 28.0, 8.0, 38.0, '-1', 19.0, '-1', '-1', 40.0, '-1', '-1', 66.0, 28.0, 42.0, '-1', 21.0, 18.0, 14.0, 40.0, 27.0, '-1', 3.0, 19.0, '-1', '-1', '-1', '-1', 18.0, 7.0, 21.0, 49.0, 29.0, 65.0, '-1', 21.0, 28.5, 5.0, 11.0, 22.0, 38.0, 45.0, 4.0, '-1', '-1', 29.0, 19.0, 17.0, 26.0, 32.0, 16.0, 21.0, 26.0, 32.0, 25.0, '-1', '-1', 0.83, 30.0, 22.0, 29.0, '-1', 28.0, 17.0, 33.0, 16.0, '-1', 23.0, 24.0, 29.0, 20.0, 46.0, 26.0, 59.0, '-1', 71.0, 23.0, 34.0, 34.0, 28.0, '-1', 21.0, 33.0, 37.0, 28.0, 21.0, '-1', 38.0, '-1', 47.0, 14.5, 22.0, 20.0, 17.0, 21.0, 70.5, 29.0, 24.0, 2.0, 21.0, '-1', 32.5, 32.5, 54.0, 12.0, '-1', 24.0, '-1', 45.0, 33.0, 20.0, 47.0, 29.0, 25.0, 23.0, 19.0, 37.0, 16.0, 24.0, '-1', 22.0, 2
# ...

# %%
train_constant.iloc[age_missing_index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
train= df.copy()
imputer= SimpleImputer(strategy='mean')
train["Age"]=imputer.fit_transform(train[["Age"]])
train.iloc[age_missing_index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df['Age']=df.groupby('Sex')['Age'].transform(lambda x: x.fillna(x.mean()))
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin           687
# Embarked          2
# sepal_length    891
# sepal_width     891
# dtype: int64

# %%
df['Cabin']=df.groupby('Sex')['Cabin'].transform(lambda x: x.fillna(x.mean()))
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f0a2a37eb1fc> in <cell line: 1>()
# ----> 1 df['Cabin']=df.groupby('Sex')['Cabin'].transform(lambda x: x.fillna(x.mean()))
#       2 df.isnull().sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/generic.py in transform(self, func, engine, engine_kwargs, *args, **kwargs)
#     515     @Appender(_transform_template)
#     516     def transform(self, func, *args, engine=None, engine_kwargs=None, **kwargs):
# --> 517         return self._transform(
#     518             func, *args, engine=engine, engine_kwargs=engine_kwargs, **kwargs
#     519         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _transform(self, func, engine, engine_kwargs, *args, **kwargs)
#    2019
#    2020         if not isinstance(func, str):
# ...

# %%
#######

# %%
### Second working Start From Here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as stat

df=pd.read_csv("/content/drive/MyDrive/Dataset Data Mining /Dataset/iris.csv")

# %%
x=df.drop("species",axis=1)
x

y=df['species']
y
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
####Machine Learning
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
y_test
# Out:
# 73     versicolor
# 18         setosa
# 118     virginica
# 78     versicolor
# 76     versicolor
# 31         setosa
# 64     versicolor
# 141     virginica
# 68     versicolor
# 82     versicolor
# 110     virginica
# 12         setosa
# 36         setosa
# 9          setosa
# 19         setosa
# 56     versicolor
# 104     virginica
# 69     versicolor
# 55     versicolor
# 132     virginica
# 29         setosa
# 127     virginica
# 26         setosa
# 128     virginica
# 131     virginica
# 145     virginica
# 108     virginica
# 143     virginica
# 45         setosa
# 30         setosa
# Name: species, dtype: object

# %%
from sklearn.linear_model import LogisticRegression
Irg = LogisticRegression()
Irg.fit(x_train,y_train)

Irg.score(x_test,y_test)*100
# Out:
# 100.0

# %%
Irg.score(x_test,y_test)*100
# Out:
# 100.0

# %% [markdown]
# [Exercise:](https://apple.com)
#
# Fill missing values on cabin & age using groupby with mean values.
#
# Normalize data on passenger id using -1 to 1 range.
#
# Apply DT & random forest.

# %%
df.loc[[1, 5, 10], 'sepal_length'] = np.nan
df.loc[[3, 8, 12], 'sepal_width'] = np.nan


df['sepal_length'] = df.groupby('species')['sepal_length'].transform(lambda x: x.fillna(x.mean()))
df['sepal_width'] = df.groupby('species')['sepal_width'].transform(lambda x: x.fillna(x.mean()))


print(df.isnull().sum())
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64
